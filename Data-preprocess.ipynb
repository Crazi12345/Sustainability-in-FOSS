# %% [markdown]
# # Data Preprocess
# ## Set up

# %%
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# ## Getting data
# Loading in data and add correct column names

# %%
df_fromgraduation = pd.read_csv("incubator_project_graduated_from_graduation.csv", header=None)
df_all = pd.read_csv("incubator_project_metrics_graduated_retired.csv", header=None)
df_bypassed = pd.read_csv("non_incubator_project_metrics.csv", header=None)

# %%
CSV_HEADERS = ['project',
                'COM-1', 'COM-2',
                'POP-1',
                'STA-1','STA-2',
                'STA-3','STA-4','STA-5','STA-6',
                'STA-7','STA-8','STA-9',
                'TEC-1','TEC-2.1','TEC-2.2','TEC-2.3','TEC-2','TEC-3','TEC-4',
                'SWQ-1',
                'SWQ-2.1','SWQ-2.2','SWQ-2.3','SWQ-2.4','SWQ-2.5','SWQ-2.6','SWQ-2.7',
                'init','end','frequency (weeks)',
                'project_url']

df_fromgraduation.columns = CSV_HEADERS
df_all.columns = CSV_HEADERS
df_bypassed.columns = CSV_HEADERS

# %% [markdown]
# The columns: TEC-2.1, TECT-2.2 and TEC-2.3 are empty and/or removed from the paper.

# %%
df_fromgraduation = df_fromgraduation.drop(columns=["TEC-2.1",'TEC-2.2','TEC-2.3'])
df_all = df_all.drop(columns=["TEC-2.1",'TEC-2.2','TEC-2.3'])
df_bypassed = df_bypassed.drop(columns=["TEC-2.1",'TEC-2.2','TEC-2.3'])

# %% [markdown]
# Checking the 3 dataframes have the correct data and headers

# %%
df_fromgraduation.head(3)
# Out:
#   project              COM-1  COM-2  POP-1                STA-1 STA-2 STA-3  \
# 0     ace  9788017.927576544   1579     77  2010-05-26 23:38:08     9    23
# 1  apisix  901329.6034821316  27592  30442  2019-04-10 02:02:05   125  2452
# 2  abdera  2938138.296738281    335     61  2009-05-21 03:21:27    34    25
#
#   STA-4  STA-5  STA-6 STA-7 STA-8 STA-9 TEC-1  TEC-2 TEC-3 TEC-4  \
# 0     2      2   True    -4    67    10     0   4022    19  1858
# 1  -223      5  False   -15  1044   383  2413  67462  2162  2406
# 2     1      2   True    -2   121    11     0  26165    35  1611
#
#                    SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  SWQ-2.5  \
# 0  0.0010720897460694647    19.66       42        0        6       15
# 1   0.009605313577723847     7.48       41        1        0       12
# 2   0.017543859649122806    55.18       40        1        0        2
#
#      SWQ-2.6  SWQ-2.7        init         end  frequency (weeks)  \
# 0   8.611501      235  2011-12-21  2020-06-17                 12
# 1  26.869675      415  2020-07-15  2024-07-12                 12
# 2   9.878605      274  2008-11-08  2020-11-26                 12
#
#                         project_url
# 0     https://github.com/apache/ace
# 1  https://github.com/apache/apisix
# 2  https://github.com/apache/abdera

# %%
df_all.head(3)
# Out:
#     project              COM-1 COM-2 POP-1                STA-1 STA-2 STA-3  \
# 0       ace  9788017.927576544   644    77  2010-05-26 23:38:08   -15    23
# 1    abdera  2938138.296738281   608    61  2009-05-21 03:21:27   286    25
# 2  airavata  6952636.983029673  1571   324  2014-01-29 08:00:06  -266   114
#
#   STA-4  STA-5  STA-6 STA-7 STA-8 STA-9 TEC-1  TEC-2 TEC-3  TEC-4  \
# 0     0      2   True     1    40     4     0   4022    19   1858
# 1     0      2   True     0    76     5     0  26165    35   1611
# 2     0      5  False     3    61     3  1112  46472   303  10526
#
#                    SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  SWQ-2.5  \
# 0  0.0010720897460694647    19.66       42        0        6       15
# 1   0.017543859649122806    55.18       40        1        0        2
# 2   0.015394894854222536     2.27        0       50       95      340
#
#      SWQ-2.6  SWQ-2.7        init         end  frequency (weeks)  \
# 0   8.611501      235  2009-04-24  2011-12-21                 12
# 1   9.878605      274  2006-06-06  2008-11-08                 12
# 2  49.897383      323  2011-05-05  2012-09-19                 12
#
#                           project_url
# 0       https://github.com/apache/ace
# 1    https://github.com/apache/abdera
# 2  https://github.com/apache/airavata

# %%
df_bypassed.head(3)
# Out:
#                project           COM-1           COM-2  POP-1  \
# 0   ant-antlibs-dotnet  Issues missing  Issues missing     17
# 1                  ant  Issues missing  Issues missing   1256
# 2  ant-antlibs-antunit  Issues missing  Issues missing     30
#
#                  STA-1  STA-2  STA-3        STA-4  STA-5  STA-6  STA-7  \
# 0  2014-05-28 07:00:08      3      7  PRs missing      1   True     -2
# 1  2014-05-28 07:00:08     34    426            1      3  False     -2
# 2  2014-05-28 07:00:07      4     14            0      1   True     -2
#
#                               STA-8  STA-9  TEC-1        TEC-2  TEC-3  TEC-4  \
# 0  Commits or Issues or PRs missing      1      0  PRs missing      0    103
# 1  Commits or Issues or PRs missing     81      1         3047    192  17094
# 2  Commits or Issues or PRs missing      6      0        23109      0    247
#
#             SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  SWQ-2.5    SWQ-2.6  \
# 0  Issues missing    47.69        3        0        0        0   4.003813
# 1  Issues missing    25.15        4        2       12       36  12.696530
# 2  Issues missing    25.40        0        0        0        0  15.920826
#
#    SWQ-2.7        init         end  frequency (weeks)  \
# 0       60  2014-05-28  2019-05-26                 12
# 1      217  2014-05-28  2024-08-18                 12
# 2       38  2014-05-28  2022-02-13                 12
#
#                                      project_url
# 0   https://github.com/apache/ant-antlibs-dotnet
# 1                  https://github.com/apache/ant
# 2  https://github.com/apache/ant-antlibs-antunit

# %% [markdown]
# ## Adding status column
#
# - Bypassed = Sustainable
# - Graduated = Sustainable
# - project is in all but not in "graduated" = Unsustainable

# %%
df_bypassed["status"] = "sustainable"
df_fromgraduation["status"] = "sustainable"

# %%
df_all["status"] = df_all["project"].isin(df_fromgraduation["project"]).map({True: "sustainable", False: "unsustainable"})
df_retired = df_all[df_all["status"] == "unsustainable"].copy()

# %% [markdown]
# Now we have the following dataframes:
# - df_bypassed: bypassed projects (sustainable)
# - df_fromgraduation: graduated projects (sustainable)
# - df_retired: retired projects (unsustainable)
#
# We combine all the dataframes to one for further processing:

# %%
df_combined = pd.concat([df_retired,df_bypassed, df_fromgraduation], ignore_index=True)

# %% [markdown]
# ## Type processing

# %%
df_combined.dtypes
# Out:
# project               object
# COM-1                 object
# COM-2                 object
# POP-1                 object
# STA-1                 object
# STA-2                 object
# STA-3                 object
# STA-4                 object
# STA-5                  int64
# STA-6                 object
# STA-7                 object
# STA-8                 object
# STA-9                 object
# TEC-1                 object
# TEC-2                 object
# TEC-3                 object
# TEC-4                 object
# SWQ-1                 object
# SWQ-2.1              float64
# SWQ-2.2                int64
# SWQ-2.3                int64
# SWQ-2.4                int64
# SWQ-2.5                int64
# SWQ-2.6              float64
# SWQ-2.7                int64
# init                  object
# end                   object
# frequency (weeks)      int64
# project_url           object
# status                object
# dtype: object

# %% [markdown]
# Change "init" and "end" columns to datatime datatype

# %%
df_combined["init"] = pd.to_datetime(df_combined["init"])
df_combined["end"] = pd.to_datetime(df_combined["end"])

# %% [markdown]
# ## Data Clean up

# %% [markdown]
# ### STA-1
#
# STA-1 should contain information about how long the project has been running. But the column only has a single date. Since we have "init" and "end" we can change this date our with the number of days between init and end.

# %%
df_combined["STA-1"]
# Out:
# 0      2011-12-04 19:45:29
# 1      2016-02-12 16:10:05
# 2      2017-04-13 19:06:57
# 3      2017-09-27 20:52:34
# 4      2016-08-28 07:00:07
#               ...
# 393      Repo info missing
# 394    2017-09-01 07:00:11
# 395    2019-12-14 23:27:55
# 396    2013-11-13 08:00:13
# 397    2017-12-20 08:00:09
# Name: STA-1, Length: 398, dtype: object

# %%
df_combined["STA-1"] = (df_combined["end"] - df_combined["init"]).dt.days / 365.25

# %% [markdown]
# ## Missing Data
# Some of the projects are missing data, with some cells noted as "missing" in the dataframe. After discussion with supervisor it was decided to remove projects with missing data from the analysis.

# %%
count_missing = df_combined.apply(lambda row: row.astype(str).str.contains('missing', case=False, na=False).any(), axis=1).sum()

print(f"Number of rows containing 'missing': {count_missing}")
# Out:
# Number of rows containing 'missing': 56

# %%
df_combined = df_combined[~df_combined.apply(lambda row: row.astype(str).str.contains('missing', case=False, na=False).any(), axis=1)]

# %% [markdown]
# Checking for NaN values:

# %%
df_combined[df_combined.isna().any(axis=1)]
# Out:
#              project               COM-1  COM-2 POP-1      STA-1 STA-2 STA-3  \
# 161  velocity-master  12298566.348089265    196     4   4.388775    -2     2
# 213          cordova  1748916.7862903227   1151  1264  11.723477     0    62
# 237            Felix   5142729.431256367  25233   896  17.273101   310   322
# 346            Sling  2693158.6690781005  42692   698  15.159480  1065   260
# 389          streams                 NaN     18   197   6.672142    19    47
#
#     STA-4  STA-5  STA-6 STA-7 STA-8 STA-9 TEC-1  TEC-2 TEC-3  TEC-4  \
# 161     0      1   True     0    44     1     0  60337     2     81
# 213     0      1   True     0    73    11     2  36686    24     25
# 237     0      2  False    -7  1365    60     0  69377  2303  35027
# 346     0      1  False    -8   810    53     0  81086  3266  46606
# 389   -18      1  False    -1    14     9   884  52879   230   1804
#
#                     SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  SWQ-2.5  \
# 161                 11.68     0.00        0        0        0        0
# 213                   0.0     0.00        0        0        0        0
# 237  0.038252949699855106     0.00        0        0        0        0
# 346  0.053478048667115995     0.00        0        0        0        0
# 389                   0.0    27.44       33        0        2        1
#
#        SWQ-2.6  SWQ-2.7       init        end  frequency (weeks)  \
# 161        NaN        0 2020-04-02 2024-08-22                 12
# 213        NaN        0 2012-10-17 2024-07-08                 12
# 237        NaN        0 2007-04-01 2024-07-09                 12
# 346        NaN        0 2009-06-17 2024-08-14                 12
# 389  31.996976      112 2017-07-19 2024-03-21                 12
#
#                                    project_url       status
# 161  https://github.com/apache/velocity-master  sustainable
# 213          https://github.com/apache/cordova  sustainable
# 237            https://github.com/apache/Felix  sustainable
# 346            https://github.com/apache/Sling  sustainable
# 389          https://github.com/apache/streams  sustainable

# %%
df_combined = df_combined.dropna()

# %%
df_combined
# Out:
#                          project               COM-1   COM-2  POP-1     STA-1  \
# 0                            awf   307880.1031494253     775    217  1.193703
# 1                    Agila-Theme   5486906.133333334       0    554  2.182067
# 2                SerializerTests   91721.18181818182       0    170  0.772074
# 3    incubator-retired-amaterasu        8753167.2676     123    139  2.028747
# 4            incubator-ariatosca   2021894.153536083    1977    103  1.842574
# ..                           ...                 ...     ...    ...       ...
# 387                        Flink   4324400.851542074  150989  60172  9.579740
# 388                       Pulsar   5351959.264741484   28047  31473  5.828884
# 394                     NetBeans   2133789.239591516    7325   6027  5.248460
# 395              incubator-NuttX   1342959.747826087    2634   6071  1.667351
# 397                        PLC4X  11618259.974489795    1203   2796  5.251198
#
#     STA-2  STA-3 STA-4  STA-5  STA-6 STA-7 STA-8 STA-9  TEC-1  TEC-2 TEC-3  \
# 0       0     11     0      1   True     0    15     1     84  27485    20
# 1       0     50     0      1   True     0     0     0      0    793    20
# 2       0     22     0      1  False     0     0     0      0  51166    22
# 3     -73     27    -1      2  False     3    24     9    426  65317    98
# 4      15     47   -26      2  False    -5    46    14     13  46687    39
# ..    ...    ...   ...    ...    ...   ...   ...   ...    ...    ...   ...
# 387   273  13102    70     16  False    56  4721  1628  12851   7828  6925
# 388  -433   3537  -358     12  False    18  1231   649   7279  64666  3295
# 394    17    835   -41      2  False   -19   417   194   5061   5772  1584
# 395   573   1059  -696      6  False   -13   377   197   2067  67554  6816
# 397   -28    390    74      2  False     1   119    78   3669  72265   395
#
#      TEC-4                  SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  \
# 0       68    0.22739018087855298     0.00        0        0        0
# 1       10                    0.0     0.00        0        0        8
# 2       81                    0.0     0.00        2        0        0
# 3      715  0.0023589963542783618    22.69        2        0        0
# 4      166    0.05902578796561605    57.47       25        0        0
# ..     ...                    ...      ...      ...      ...      ...
# 387  40618   0.017610098391586823   113.40        0       21       65
# 388  17031   0.015899818366024405    98.41        0        5       42
# 394  10109  0.0033561969508432224    32.87        0       50      523
# 395  46970                    0.0     0.02        0       50      452
# 397   8525  0.0011259210199519828    18.03        0       50       63
#
#      SWQ-2.5    SWQ-2.6  SWQ-2.7       init        end  frequency (weeks)  \
# 0          1   0.000000      574 2011-07-08 2012-09-16                 12
# 1          0  87.263707       22 2004-09-29 2006-12-05                 12
# 2          1  11.027687      196 2010-09-21 2011-06-30                 12
# 3          1  16.620933      154 2017-09-07 2019-09-18                 12
# 4          0   4.990767       85 2016-08-27 2018-07-01                 12
# ..       ...        ...      ...        ...        ...                ...
# 387      214  14.329816      436 2014-12-17 2024-07-16                 12
# 388      109  11.537613      327 2018-09-19 2024-07-18                 12
# 394     1844  26.921600     2498 2019-04-17 2024-07-16                 12
# 395     1230  36.079518     1513 2022-11-17 2024-07-18                 12
# 397      531  17.646239     5637 2019-04-17 2024-07-17                 12
#
#                                            project_url         status
# 0                          https://github.com/valr/awf  unsustainable
# 1                  https://github.com/arvi/Agila-Theme  unsustainable
# 2          https://github.com/Alois-xx/SerializerTests  unsustainable
# 3    https://github.com/apache/incubator-retired-am...  unsustainable
# 4        https://github.com/apache/incubator-ariatosca  unsustainable
# ..                                                 ...            ...
# 387                    https://github.com/apache/Flink    sustainable
# 388                   https://github.com/apache/Pulsar    sustainable
# 394                 https://github.com/apache/NetBeans    sustainable
# 395          https://github.com/apache/incubator-NuttX    sustainable
# 397                    https://github.com/apache/PLC4X    sustainable
#
# [337 rows x 30 columns]

# %% [markdown]
# # Saving the cleaned data to CSV

# %%
df_combined.to_csv("all_projects.csv", index=False)
