# %% [markdown]
# # Data Preprocess
# Data imports

# %%
import pandas as pd

# %% [markdown]
# Loading in data and giving it column names

# %%
df_fromgraduation = pd.read_csv("incubator_project_graduated_from_graduation.csv", header=None)
df_all = pd.read_csv("incubator_project_metrics_graduated_retired.csv", header=None)
df_bypassed = pd.read_csv("non_incubator_project_metrics.csv", header=None)

# %%
CSV_HEADERS = ['project',
                'COM-1', 'COM-3',
                'POP-4',
                'STA-1','STA-2',
                'STA-4','STA-5','STA-6','STA-7',
                'STA-10','STA-11','STA-12',
                'TEC-1','TEC-2.1','TEC-2.2','TEC-2.3','TEC-2.4','TEC-4','TEC-5',
                'SWQ-1',
                'SWQ-4.1','SWQ-4.2','SWQ-4.3','SWQ-4.4','SWQ-4.5','SWQ-4.6','SWQ-4.7',
                'init','end','frequency (weeks)',
                'project_url']

df_fromgraduation.columns = CSV_HEADERS
df_all.columns = CSV_HEADERS
df_bypassed.columns = CSV_HEADERS

# %%
df_fromgraduation.head(3)
# Out:
#   project              COM-1  COM-3  POP-4                STA-1 STA-2 STA-4  \
# 0     ace  9788017.927576544   1579     77  2010-05-26 23:38:08     9    23
# 1  apisix  901329.6034821316  27592  30442  2019-04-10 02:02:05   125  2452
# 2  abdera  2938138.296738281    335     61  2009-05-21 03:21:27    34    25
#
#   STA-5  STA-6  STA-7 STA-10 STA-11 STA-12 TEC-1  TEC-2.1 TEC-2.2  TEC-2.3  \
# 0     2      2   True     -4     67     10     0      NaN      -1      NaN
# 1  -223      5  False    -15   1044    383  2413      NaN    7498      NaN
# 2     1      2   True     -2    121     11     0      NaN      -1      NaN
#
#   TEC-2.4 TEC-4 TEC-5                  SWQ-1  SWQ-4.1  SWQ-4.2  SWQ-4.3  \
# 0    4022    19  1858  0.0010720897460694647    19.66       42        0
# 1   67462  2162  2406   0.009605313577723847     7.48       41        1
# 2   26165    35  1611   0.017543859649122806    55.18       40        1
#
#    SWQ-4.4  SWQ-4.5    SWQ-4.6  SWQ-4.7        init         end  \
# 0        6       15   8.611501      235  2011-12-21  2020-06-17
# 1        0       12  26.869675      415  2020-07-15  2024-07-12
# 2        0        2   9.878605      274  2008-11-08  2020-11-26
#
#    frequency (weeks)                       project_url
# 0                 12     https://github.com/apache/ace
# 1                 12  https://github.com/apache/apisix
# 2                 12  https://github.com/apache/abdera

# %%
df_all.head(3)
# Out:
#     project              COM-1 COM-3 POP-4                STA-1 STA-2 STA-4  \
# 0       ace  9788017.927576544   644    77  2010-05-26 23:38:08   -15    23
# 1    abdera  2938138.296738281   608    61  2009-05-21 03:21:27   286    25
# 2  airavata  6952636.983029673  1571   324  2014-01-29 08:00:06  -266   114
#
#   STA-5  STA-6  STA-7 STA-10 STA-11 STA-12 TEC-1  TEC-2.1 TEC-2.2  TEC-2.3  \
# 0     0      2   True      1     40      4     0      NaN      -1      NaN
# 1     0      2   True      0     76      5     0      NaN      -1      NaN
# 2     0      5  False      3     61      3  1112      NaN   83692      NaN
#
#   TEC-2.4 TEC-4  TEC-5                  SWQ-1  SWQ-4.1  SWQ-4.2  SWQ-4.3  \
# 0    4022    19   1858  0.0010720897460694647    19.66       42        0
# 1   26165    35   1611   0.017543859649122806    55.18       40        1
# 2   46472   303  10526   0.015394894854222536     2.27        0       50
#
#    SWQ-4.4  SWQ-4.5    SWQ-4.6  SWQ-4.7        init         end  \
# 0        6       15   8.611501      235  2009-04-24  2011-12-21
# 1        0        2   9.878605      274  2006-06-06  2008-11-08
# 2       95      340  49.897383      323  2011-05-05  2012-09-19
#
#    frequency (weeks)                         project_url
# 0                 12       https://github.com/apache/ace
# 1                 12    https://github.com/apache/abdera
# 2                 12  https://github.com/apache/airavata

# %%
df_bypassed.head(3)
# Out:
#                project           COM-1           COM-3  POP-4  \
# 0   ant-antlibs-dotnet  Issues missing  Issues missing     17
# 1                  ant  Issues missing  Issues missing   1256
# 2  ant-antlibs-antunit  Issues missing  Issues missing     30
#
#                  STA-1  STA-2  STA-4        STA-5  STA-6  STA-7  STA-10  \
# 0  2014-05-28 07:00:08      3      7  PRs missing      1   True      -2
# 1  2014-05-28 07:00:08     34    426            1      3  False      -2
# 2  2014-05-28 07:00:07      4     14            0      1   True      -2
#
#                              STA-11  STA-12  TEC-1  TEC-2.1      TEC-2.2  \
# 0  Commits or Issues or PRs missing       1      0      NaN  PRs missing
# 1  Commits or Issues or PRs missing      81      1      NaN           -1
# 2  Commits or Issues or PRs missing       6      0      NaN           -1
#
#    TEC-2.3      TEC-2.4  TEC-4  TEC-5           SWQ-1  SWQ-4.1  SWQ-4.2  \
# 0      NaN  PRs missing      0    103  Issues missing    47.69        3
# 1      NaN         3047    192  17094  Issues missing    25.15        4
# 2      NaN        23109      0    247  Issues missing    25.40        0
#
#    SWQ-4.3  SWQ-4.4  SWQ-4.5    SWQ-4.6  SWQ-4.7        init         end  \
# 0        0        0        0   4.003813       60  2014-05-28  2019-05-26
# 1        2       12       36  12.696530      217  2014-05-28  2024-08-18
# 2        0        0        0  15.920826       38  2014-05-28  2022-02-13
#
#    frequency (weeks)                                    project_url
# 0                 12   https://github.com/apache/ant-antlibs-dotnet
# 1                 12                  https://github.com/apache/ant
# 2                 12  https://github.com/apache/ant-antlibs-antunit

# %%
df_bypassed["status"] = "sustainable"

# %%
df_bypassed.head(3)
# Out:
#                project           COM-1           COM-3  POP-4  \
# 0   ant-antlibs-dotnet  Issues missing  Issues missing     17
# 1                  ant  Issues missing  Issues missing   1256
# 2  ant-antlibs-antunit  Issues missing  Issues missing     30
#
#                  STA-1  STA-2  STA-4        STA-5  STA-6  STA-7  STA-10  \
# 0  2014-05-28 07:00:08      3      7  PRs missing      1   True      -2
# 1  2014-05-28 07:00:08     34    426            1      3  False      -2
# 2  2014-05-28 07:00:07      4     14            0      1   True      -2
#
#                              STA-11  STA-12  TEC-1  TEC-2.1      TEC-2.2  \
# 0  Commits or Issues or PRs missing       1      0      NaN  PRs missing
# 1  Commits or Issues or PRs missing      81      1      NaN           -1
# 2  Commits or Issues or PRs missing       6      0      NaN           -1
#
#    TEC-2.3      TEC-2.4  TEC-4  TEC-5           SWQ-1  SWQ-4.1  SWQ-4.2  \
# 0      NaN  PRs missing      0    103  Issues missing    47.69        3
# 1      NaN         3047    192  17094  Issues missing    25.15        4
# 2      NaN        23109      0    247  Issues missing    25.40        0
#
#    SWQ-4.3  SWQ-4.4  SWQ-4.5    SWQ-4.6  SWQ-4.7        init         end  \
# 0        0        0        0   4.003813       60  2014-05-28  2019-05-26
# 1        2       12       36  12.696530      217  2014-05-28  2024-08-18
# 2        0        0        0  15.920826       38  2014-05-28  2022-02-13
#
#    frequency (weeks)                                    project_url  \
# 0                 12   https://github.com/apache/ant-antlibs-dotnet
# 1                 12                  https://github.com/apache/ant
# 2                 12  https://github.com/apache/ant-antlibs-antunit
#
#         status
# 0  sustainable
# 1  sustainable
# 2  sustainable

# %%
df_fromgraduation["status"] = "sustainable"

# %%
df_fromgraduation.head(3)
# Out:
#   project              COM-1  COM-3  POP-4                STA-1 STA-2 STA-4  \
# 0     ace  9788017.927576544   1579     77  2010-05-26 23:38:08     9    23
# 1  apisix  901329.6034821316  27592  30442  2019-04-10 02:02:05   125  2452
# 2  abdera  2938138.296738281    335     61  2009-05-21 03:21:27    34    25
#
#   STA-5  STA-6  STA-7 STA-10 STA-11 STA-12 TEC-1  TEC-2.1 TEC-2.2  TEC-2.3  \
# 0     2      2   True     -4     67     10     0      NaN      -1      NaN
# 1  -223      5  False    -15   1044    383  2413      NaN    7498      NaN
# 2     1      2   True     -2    121     11     0      NaN      -1      NaN
#
#   TEC-2.4 TEC-4 TEC-5                  SWQ-1  SWQ-4.1  SWQ-4.2  SWQ-4.3  \
# 0    4022    19  1858  0.0010720897460694647    19.66       42        0
# 1   67462  2162  2406   0.009605313577723847     7.48       41        1
# 2   26165    35  1611   0.017543859649122806    55.18       40        1
#
#    SWQ-4.4  SWQ-4.5    SWQ-4.6  SWQ-4.7        init         end  \
# 0        6       15   8.611501      235  2011-12-21  2020-06-17
# 1        0       12  26.869675      415  2020-07-15  2024-07-12
# 2        0        2   9.878605      274  2008-11-08  2020-11-26
#
#    frequency (weeks)                       project_url       status
# 0                 12     https://github.com/apache/ace  sustainable
# 1                 12  https://github.com/apache/apisix  sustainable
# 2                 12  https://github.com/apache/abdera  sustainable

# %% [markdown]
# ## Adding status column

# %%
df_all["status"] = df_all["project"].isin(df_fromgraduation["project"]).map({True: "sustainable", False: "unsustainable"})

# %%
df_all
# Out:
#              project               COM-1           COM-3  POP-4  \
# 0                ace   9788017.927576544             644     77
# 1             abdera   2938138.296738281             608     61
# 2           airavata   6952636.983029673            1571    324
# 3                age   3819620.014249615             590   6087
# 4             apisix   901329.6034821316            2035  30442
# ..               ...                 ...             ...    ...
# 278         NetBeans   2133789.239591516               0   6027
# 279       openoffice      Issues missing  Issues missing   2158
# 280            PLC4X  11618259.974489795               0   2796
# 281       ODFToolkit      Issues missing  Issues missing     94
# 282  incubator-NuttX   1342959.747826087            2884   6071
#
#                    STA-1  STA-2 STA-4 STA-5  STA-6  STA-7 STA-10  \
# 0    2010-05-26 23:38:08    -15    23     0      2   True      1
# 1    2009-05-21 03:21:27    286    25     0      2   True      0
# 2    2014-01-29 08:00:06   -266   114     0      5  False      3
# 3    2020-07-01 06:15:47      5   401    14      5  False      8
# 4    2019-04-10 02:02:05    -15  2452    29      5  False     -5
# ..                   ...    ...   ...   ...    ...    ...    ...
# 278  2017-09-01 07:00:11   -241   835   159      2  False     32
# 279  2013-11-13 08:00:13  -1056   308     0      2  False     14
# 280  2017-12-20 08:00:09    223   390    10      2  False     -1
# 281  2012-07-28 07:00:12   1014    24     0      1   True     -3
# 282  2019-12-14 23:27:55   -222  1059   261      6  False     25
#
#                                STA-11 STA-12 TEC-1  TEC-2.1 TEC-2.2  TEC-2.3  \
# 0                                  40      4     0      NaN      -1      NaN
# 1                                  76      5     0      NaN      -1      NaN
# 2                                  61      3  1112      NaN   83692      NaN
# 3                                  77     17   578      NaN   63875      NaN
# 4                                 161     32  2413      NaN    7498      NaN
# ..                                ...    ...   ...      ...     ...      ...
# 278                               150     97  5061      NaN   72166      NaN
# 279  Commits or Issues or PRs missing     11  4061      NaN   53896      NaN
# 280                                26      8  3669      NaN    3940      NaN
# 281  Commits or Issues or PRs missing     10     0      NaN      -1      NaN
# 282                               438    248  2067      NaN   45510      NaN
#
#     TEC-2.4 TEC-4  TEC-5                  SWQ-1  SWQ-4.1  SWQ-4.2  SWQ-4.3  \
# 0      4022    19   1858  0.0010720897460694647    19.66       42        0
# 1     26165    35   1611   0.017543859649122806    55.18       40        1
# 2     46472   303  10526   0.015394894854222536     2.27        0       50
# 3     81544   269   1188  0.0007904797493460576     5.09       35        2
# 4     67462  2162   2406  7.663814024779666e-05     7.48       41        1
# ..      ...   ...    ...                    ...      ...      ...      ...
# 278    5772  1584  10109  0.0033561969508432224    32.87        0       50
# 279   34837   475  17091         Issues missing     5.69        0       50
# 280   72265   395   8525  0.0011259210199519828    18.03        0       50
# 281      -1   120   1200         Issues missing    13.97       30        2
# 282   67554  6816  46970                    0.0     0.02        0       50
#
#      SWQ-4.4  SWQ-4.5    SWQ-4.6  SWQ-4.7        init         end  \
# 0          6       15   8.611501      235  2009-04-24  2011-12-21
# 1          0        2   9.878605      274  2006-06-06  2008-11-08
# 2         95      340  49.897383      323  2011-05-05  2012-09-19
# 3         11       20  15.380107      279  2020-04-29  2022-05-18
# 4          0       12  26.869675      415  2019-10-17  2020-07-15
# ..       ...      ...        ...      ...         ...         ...
# 278      523     1844  26.921600     2498  2016-10-01  2019-04-17
# 279      179      650  18.556351     2010  2011-06-13  2012-10-17
# 280       63      531  17.646239     5637  2017-12-18  2019-04-17
# 281       17       23  63.752815      259  2011-08-01  2018-11-27
# 282      452     1230  36.079518     1513  2019-12-09  2022-11-17
#
#      frequency (weeks)                                project_url  \
# 0                   12              https://github.com/apache/ace
# 1                   12           https://github.com/apache/abdera
# 2                   12         https://github.com/apache/airavata
# 3                   12              https://github.com/apache/age
# 4                   12           https://github.com/apache/apisix
# ..                 ...                                        ...
# 278                 12         https://github.com/apache/NetBeans
# 279                 12       https://github.com/apache/openoffice
# 280                 12            https://github.com/apache/PLC4X
# 281                 12       https://github.com/apache/ODFToolkit
# 282                 12  https://github.com/apache/incubator-NuttX
#
#             status
# 0      sustainable
# 1      sustainable
# 2      sustainable
# 3      sustainable
# 4      sustainable
# ..             ...
# 278    sustainable
# 279    sustainable
# 280    sustainable
# 281  unsustainable
# 282    sustainable
#
# [283 rows x 33 columns]

# %%
df_retired = df_all[df_all["status"] == "unsustainable"].copy()

# %%
df_combined = pd.concat([df_retired,df_bypassed, df_fromgraduation], ignore_index=True)

# %%
df_combined
# Out:
#                          project               COM-1           COM-3  \
# 0                            awf   307880.1031494253             775
# 1                    Agila-Theme   5486906.133333334               0
# 2                SerializerTests   91721.18181818182               0
# 3    incubator-retired-amaterasu        8753167.2676             123
# 4            incubator-ariatosca   2021894.153536083            1977
# ..                           ...                 ...             ...
# 278                      jclouds      Issues missing  Issues missing
# 279                     NetBeans   2133789.239591516            7325
# 280              incubator-NuttX   1342959.747826087            2634
# 281                   openoffice      Issues missing  Issues missing
# 282                        PLC4X  11618259.974489795            1203
#
#                  POP-4                STA-1 STA-2              STA-4  \
# 0                  217  2011-12-04 19:45:29     0                 11
# 1                  554  2016-02-12 16:10:05     0                 50
# 2                  170  2017-04-13 19:06:57     0                 22
# 3                  139  2017-09-27 20:52:34   -73                 27
# 4                  103  2016-08-28 07:00:07    15                 47
# ..                 ...                  ...   ...                ...
# 278  Repo info missing    Repo info missing   135  Repo info missing
# 279               6027  2017-09-01 07:00:11    17                835
# 280               6071  2019-12-14 23:27:55   573               1059
# 281               2158  2013-11-13 08:00:13   491                308
# 282               2796  2017-12-20 08:00:09   -28                390
#
#            STA-5  STA-6  STA-7 STA-10                            STA-11  \
# 0              0      1   True      0                                15
# 1              0      1   True      0                                 0
# 2              0      1  False      0                                 0
# 3             -1      2  False      3                                24
# 4            -26      2  False     -5                                46
# ..           ...    ...    ...    ...                               ...
# 278  PRs missing      3  False    -15  Commits or Issues or PRs missing
# 279          -41      2  False    -19                               417
# 280         -696      6  False    -13                               377
# 281           12      2  False    -16  Commits or Issues or PRs missing
# 282           74      2  False      1                               119
#
#     STA-12 TEC-1  TEC-2.1      TEC-2.2  TEC-2.3      TEC-2.4 TEC-4  TEC-5  \
# 0        1    84      NaN           -1      NaN        27485    20     68
# 1        0     0      NaN           -1      NaN          793    20     10
# 2        0     0      NaN           -1      NaN        51166    22     81
# 3        9   426      NaN         8382      NaN        65317    98    715
# 4       14    13      NaN        76543      NaN        46687    39    166
# ..     ...   ...      ...          ...      ...          ...   ...    ...
# 278    222     0      NaN  PRs missing      NaN  PRs missing   538  12101
# 279    194  5061      NaN        72166      NaN         5772  1584  10109
# 280    197  2067      NaN        45510      NaN        67554  6816  46970
# 281     87  4061      NaN        53896      NaN        34837   475  17091
# 282     78  3669      NaN         3940      NaN        72265   395   8525
#
#                      SWQ-1  SWQ-4.1  SWQ-4.2  SWQ-4.3  SWQ-4.4  SWQ-4.5  \
# 0      0.22739018087855298     0.00        0        0        0        1
# 1                      0.0     0.00        0        0        8        0
# 2                      0.0     0.00        2        0        0        1
# 3    0.0023589963542783618    22.69        2        0        0        1
# 4      0.05902578796561605    57.47       25        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 278         Issues missing    79.03       12        4        1       16
# 279  0.0033561969508432224    32.87        0       50      523     1844
# 280                    0.0     0.02        0       50      452     1230
# 281         Issues missing     5.69        0       50      179      650
# 282  0.0011259210199519828    18.03        0       50       63      531
#
#        SWQ-4.6  SWQ-4.7        init         end  frequency (weeks)  \
# 0     0.000000      574  2011-07-08  2012-09-16                 12
# 1    87.263707       22  2004-09-29  2006-12-05                 12
# 2    11.027687      196  2010-09-21  2011-06-30                 12
# 3    16.620933      154  2017-09-07  2019-09-18                 12
# 4     4.990767       85  2016-08-27  2018-07-01                 12
# ..         ...      ...         ...         ...                ...
# 278  11.556166      210  2013-10-16  2024-05-12                 12
# 279  26.921600     2498  2019-04-17  2024-07-16                 12
# 280  36.079518     1513  2022-11-17  2024-07-18                 12
# 281  18.556351     2010  2012-10-17  2024-07-09                 12
# 282  17.646239     5637  2019-04-17  2024-07-17                 12
#
#                                            project_url         status
# 0                          https://github.com/valr/awf  unsustainable
# 1                  https://github.com/arvi/Agila-Theme  unsustainable
# 2          https://github.com/Alois-xx/SerializerTests  unsustainable
# 3    https://github.com/apache/incubator-retired-am...  unsustainable
# 4        https://github.com/apache/incubator-ariatosca  unsustainable
# ..                                                 ...            ...
# 278                  https://github.com/apache/jclouds    sustainable
# 279                 https://github.com/apache/NetBeans    sustainable
# 280          https://github.com/apache/incubator-NuttX    sustainable
# 281               https://github.com/apache/openoffice    sustainable
# 282                    https://github.com/apache/PLC4X    sustainable
#
# [283 rows x 33 columns]

# %% [markdown]
# ## Type processing

# %%
df_combined["init"] = pd.to_datetime(df_combined["init"])
df_combined["end"] = pd.to_datetime(df_combined["end"])

# %%
df_combined.dtypes
# Out:
# project                      object
# COM-1                        object
# COM-3                        object
# POP-4                        object
# STA-1                        object
# STA-2                        object
# STA-4                        object
# STA-5                        object
# STA-6                         int64
# STA-7                        object
# STA-10                       object
# STA-11                       object
# STA-12                       object
# TEC-1                        object
# TEC-2.1                     float64
# TEC-2.2                      object
# TEC-2.3                     float64
# TEC-2.4                      object
# TEC-4                        object
# TEC-5                        object
# SWQ-1                        object
# SWQ-4.1                     float64
# SWQ-4.2                       int64
# SWQ-4.3                       int64
# SWQ-4.4                       int64
# SWQ-4.5                       int64
# SWQ-4.6                     float64
# SWQ-4.7                       int64
# init                 datetime64[ns]
# end                  datetime64[ns]
# frequency (weeks)             int64
# project_url                  object
# status                       object
# dtype: object

# %%
df_combined["STA-1"] = (df_combined["end"] - df_combined["init"]).dt.days / 365.25

# %% [markdown]
# ## Checking columns

# %%
pd.set_option('display.max_columns', None)
df_combined
# Out:
#                          project               COM-1           COM-3  \
# 0                            awf   307880.1031494253             775
# 1                    Agila-Theme   5486906.133333334               0
# 2                SerializerTests   91721.18181818182               0
# 3    incubator-retired-amaterasu        8753167.2676             123
# 4            incubator-ariatosca   2021894.153536083            1977
# ..                           ...                 ...             ...
# 278                      jclouds      Issues missing  Issues missing
# 279                     NetBeans   2133789.239591516            7325
# 280              incubator-NuttX   1342959.747826087            2634
# 281                   openoffice      Issues missing  Issues missing
# 282                        PLC4X  11618259.974489795            1203
#
#                  POP-4      STA-1 STA-2              STA-4        STA-5  \
# 0                  217   1.193703     0                 11            0
# 1                  554   2.182067     0                 50            0
# 2                  170   0.772074     0                 22            0
# 3                  139   2.028747   -73                 27           -1
# 4                  103   1.842574    15                 47          -26
# ..                 ...        ...   ...                ...          ...
# 278  Repo info missing  10.570842   135  Repo info missing  PRs missing
# 279               6027   5.248460    17                835          -41
# 280               6071   1.667351   573               1059         -696
# 281               2158  11.726215   491                308           12
# 282               2796   5.251198   -28                390           74
#
#      STA-6  STA-7 STA-10                            STA-11 STA-12 TEC-1  \
# 0        1   True      0                                15      1    84
# 1        1   True      0                                 0      0     0
# 2        1  False      0                                 0      0     0
# 3        2  False      3                                24      9   426
# 4        2  False     -5                                46     14    13
# ..     ...    ...    ...                               ...    ...   ...
# 278      3  False    -15  Commits or Issues or PRs missing    222     0
# 279      2  False    -19                               417    194  5061
# 280      6  False    -13                               377    197  2067
# 281      2  False    -16  Commits or Issues or PRs missing     87  4061
# 282      2  False      1                               119     78  3669
#
#      TEC-2.1      TEC-2.2  TEC-2.3      TEC-2.4 TEC-4  TEC-5  \
# 0        NaN           -1      NaN        27485    20     68
# 1        NaN           -1      NaN          793    20     10
# 2        NaN           -1      NaN        51166    22     81
# 3        NaN         8382      NaN        65317    98    715
# 4        NaN        76543      NaN        46687    39    166
# ..       ...          ...      ...          ...   ...    ...
# 278      NaN  PRs missing      NaN  PRs missing   538  12101
# 279      NaN        72166      NaN         5772  1584  10109
# 280      NaN        45510      NaN        67554  6816  46970
# 281      NaN        53896      NaN        34837   475  17091
# 282      NaN         3940      NaN        72265   395   8525
#
#                      SWQ-1  SWQ-4.1  SWQ-4.2  SWQ-4.3  SWQ-4.4  SWQ-4.5  \
# 0      0.22739018087855298     0.00        0        0        0        1
# 1                      0.0     0.00        0        0        8        0
# 2                      0.0     0.00        2        0        0        1
# 3    0.0023589963542783618    22.69        2        0        0        1
# 4      0.05902578796561605    57.47       25        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 278         Issues missing    79.03       12        4        1       16
# 279  0.0033561969508432224    32.87        0       50      523     1844
# 280                    0.0     0.02        0       50      452     1230
# 281         Issues missing     5.69        0       50      179      650
# 282  0.0011259210199519828    18.03        0       50       63      531
#
#        SWQ-4.6  SWQ-4.7       init        end  frequency (weeks)  \
# 0     0.000000      574 2011-07-08 2012-09-16                 12
# 1    87.263707       22 2004-09-29 2006-12-05                 12
# 2    11.027687      196 2010-09-21 2011-06-30                 12
# 3    16.620933      154 2017-09-07 2019-09-18                 12
# 4     4.990767       85 2016-08-27 2018-07-01                 12
# ..         ...      ...        ...        ...                ...
# 278  11.556166      210 2013-10-16 2024-05-12                 12
# 279  26.921600     2498 2019-04-17 2024-07-16                 12
# 280  36.079518     1513 2022-11-17 2024-07-18                 12
# 281  18.556351     2010 2012-10-17 2024-07-09                 12
# 282  17.646239     5637 2019-04-17 2024-07-17                 12
#
#                                            project_url         status
# 0                          https://github.com/valr/awf  unsustainable
# 1                  https://github.com/arvi/Agila-Theme  unsustainable
# 2          https://github.com/Alois-xx/SerializerTests  unsustainable
# 3    https://github.com/apache/incubator-retired-am...  unsustainable
# 4        https://github.com/apache/incubator-ariatosca  unsustainable
# ..                                                 ...            ...
# 278                  https://github.com/apache/jclouds    sustainable
# 279                 https://github.com/apache/NetBeans    sustainable
# 280          https://github.com/apache/incubator-NuttX    sustainable
# 281               https://github.com/apache/openoffice    sustainable
# 282                    https://github.com/apache/PLC4X    sustainable
#
# [283 rows x 33 columns]

# %%
df_combined["TEC-2.3"].tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
df_combined = df_combined.drop(columns=["TEC-2.1",'TEC-2.2','TEC-2.3'])

# %%
df_combined.rename(columns=
           #  impl    |  paper
           {'COM-1'   : 'COM-1',
            'COM-3'   : 'COM-2',
            'POP-4'   : 'POP-1',
            'STA-1'   : 'STA-1',
            'STA-2'   : 'STA-2',
            'STA-4'   : 'STA-3',
            'STA-5'   : 'STA-4',
            'STA-6'   : 'STA-5',
            'STA-7'   : 'STA-6',
            'STA-2'   : 'STA-2',
            'STA-10'  : 'STA-7',
            'STA-11'  : 'STA-8',
            'STA-12'  : 'STA-9',
            'TEC-1'   : 'TEC-1',
            'TEC-2.4' : 'TEC-2',
            'TEC-4'   : 'TEC-3',
            'TEC-5'   : 'TEC-4',
            'SWQ-1'   : 'SWQ-1',
            'SWQ-4.1' : 'SWQ-2.1',
            'SWQ-4.2' : 'SWQ-2.2',
            'SWQ-4.3' : 'SWQ-2.3',
            'SWQ-4.4' : 'SWQ-2.4',
            'SWQ-4.5' : 'SWQ-2.5',
            'SWQ-4.6' : 'SWQ-2.6',
            'SWQ-4.7' : 'SWQ-2.7',
            },
            inplace=True)

# %%
df_combined
# Out:
#                          project               COM-1           COM-2  \
# 0                            awf   307880.1031494253             775
# 1                    Agila-Theme   5486906.133333334               0
# 2                SerializerTests   91721.18181818182               0
# 3    incubator-retired-amaterasu        8753167.2676             123
# 4            incubator-ariatosca   2021894.153536083            1977
# ..                           ...                 ...             ...
# 278                      jclouds      Issues missing  Issues missing
# 279                     NetBeans   2133789.239591516            7325
# 280              incubator-NuttX   1342959.747826087            2634
# 281                   openoffice      Issues missing  Issues missing
# 282                        PLC4X  11618259.974489795            1203
#
#                  POP-1      STA-1 STA-2              STA-3        STA-4  \
# 0                  217   1.193703     0                 11            0
# 1                  554   2.182067     0                 50            0
# 2                  170   0.772074     0                 22            0
# 3                  139   2.028747   -73                 27           -1
# 4                  103   1.842574    15                 47          -26
# ..                 ...        ...   ...                ...          ...
# 278  Repo info missing  10.570842   135  Repo info missing  PRs missing
# 279               6027   5.248460    17                835          -41
# 280               6071   1.667351   573               1059         -696
# 281               2158  11.726215   491                308           12
# 282               2796   5.251198   -28                390           74
#
#      STA-5  STA-6 STA-7                             STA-8 STA-9 TEC-1  \
# 0        1   True     0                                15     1    84
# 1        1   True     0                                 0     0     0
# 2        1  False     0                                 0     0     0
# 3        2  False     3                                24     9   426
# 4        2  False    -5                                46    14    13
# ..     ...    ...   ...                               ...   ...   ...
# 278      3  False   -15  Commits or Issues or PRs missing   222     0
# 279      2  False   -19                               417   194  5061
# 280      6  False   -13                               377   197  2067
# 281      2  False   -16  Commits or Issues or PRs missing    87  4061
# 282      2  False     1                               119    78  3669
#
#            TEC-2 TEC-3  TEC-4                  SWQ-1  SWQ-2.1  SWQ-2.2  \
# 0          27485    20     68    0.22739018087855298     0.00        0
# 1            793    20     10                    0.0     0.00        0
# 2          51166    22     81                    0.0     0.00        2
# 3          65317    98    715  0.0023589963542783618    22.69        2
# 4          46687    39    166    0.05902578796561605    57.47       25
# ..           ...   ...    ...                    ...      ...      ...
# 278  PRs missing   538  12101         Issues missing    79.03       12
# 279         5772  1584  10109  0.0033561969508432224    32.87        0
# 280        67554  6816  46970                    0.0     0.02        0
# 281        34837   475  17091         Issues missing     5.69        0
# 282        72265   395   8525  0.0011259210199519828    18.03        0
#
#      SWQ-2.3  SWQ-2.4  SWQ-2.5    SWQ-2.6  SWQ-2.7       init        end  \
# 0          0        0        1   0.000000      574 2011-07-08 2012-09-16
# 1          0        8        0  87.263707       22 2004-09-29 2006-12-05
# 2          0        0        1  11.027687      196 2010-09-21 2011-06-30
# 3          0        0        1  16.620933      154 2017-09-07 2019-09-18
# 4          0        0        0   4.990767       85 2016-08-27 2018-07-01
# ..       ...      ...      ...        ...      ...        ...        ...
# 278        4        1       16  11.556166      210 2013-10-16 2024-05-12
# 279       50      523     1844  26.921600     2498 2019-04-17 2024-07-16
# 280       50      452     1230  36.079518     1513 2022-11-17 2024-07-18
# 281       50      179      650  18.556351     2010 2012-10-17 2024-07-09
# 282       50       63      531  17.646239     5637 2019-04-17 2024-07-17
#
#      frequency (weeks)                                        project_url  \
# 0                   12                        https://github.com/valr/awf
# 1                   12                https://github.com/arvi/Agila-Theme
# 2                   12        https://github.com/Alois-xx/SerializerTests
# 3                   12  https://github.com/apache/incubator-retired-am...
# 4                   12      https://github.com/apache/incubator-ariatosca
# ..                 ...                                                ...
# 278                 12                  https://github.com/apache/jclouds
# 279                 12                 https://github.com/apache/NetBeans
# 280                 12          https://github.com/apache/incubator-NuttX
# 281                 12               https://github.com/apache/openoffice
# 282                 12                    https://github.com/apache/PLC4X
#
#             status
# 0    unsustainable
# 1    unsustainable
# 2    unsustainable
# 3    unsustainable
# 4    unsustainable
# ..             ...
# 278    sustainable
# 279    sustainable
# 280    sustainable
# 281    sustainable
# 282    sustainable
#
# [283 rows x 30 columns]

# %%
df_combined = df_combined[~df_combined.apply(lambda row: row.astype(str).str.contains('missing', case=False, na=False).any(), axis=1)]

# %%
df_combined
# Out:
#                          project               COM-1  COM-2  POP-1     STA-1  \
# 0                            awf   307880.1031494253    775    217  1.193703
# 1                    Agila-Theme   5486906.133333334      0    554  2.182067
# 2                SerializerTests   91721.18181818182      0    170  0.772074
# 3    incubator-retired-amaterasu        8753167.2676    123    139  2.028747
# 4            incubator-ariatosca   2021894.153536083   1977    103  1.842574
# ..                           ...                 ...    ...    ...       ...
# 273                       Pulsar   5351959.264741484  28047  31473  5.828884
# 274                      streams                 NaN     18    197  6.672142
# 279                     NetBeans   2133789.239591516   7325   6027  5.248460
# 280              incubator-NuttX   1342959.747826087   2634   6071  1.667351
# 282                        PLC4X  11618259.974489795   1203   2796  5.251198
#
#     STA-2 STA-3 STA-4  STA-5  STA-6 STA-7 STA-8 STA-9 TEC-1  TEC-2 TEC-3  \
# 0       0    11     0      1   True     0    15     1    84  27485    20
# 1       0    50     0      1   True     0     0     0     0    793    20
# 2       0    22     0      1  False     0     0     0     0  51166    22
# 3     -73    27    -1      2  False     3    24     9   426  65317    98
# 4      15    47   -26      2  False    -5    46    14    13  46687    39
# ..    ...   ...   ...    ...    ...   ...   ...   ...   ...    ...   ...
# 273  -433  3537  -358     12  False    18  1231   649  7279  64666  3295
# 274    19    47   -18      1  False    -1    14     9   884  52879   230
# 279    17   835   -41      2  False   -19   417   194  5061   5772  1584
# 280   573  1059  -696      6  False   -13   377   197  2067  67554  6816
# 282   -28   390    74      2  False     1   119    78  3669  72265   395
#
#      TEC-4                  SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  \
# 0       68    0.22739018087855298     0.00        0        0        0
# 1       10                    0.0     0.00        0        0        8
# 2       81                    0.0     0.00        2        0        0
# 3      715  0.0023589963542783618    22.69        2        0        0
# 4      166    0.05902578796561605    57.47       25        0        0
# ..     ...                    ...      ...      ...      ...      ...
# 273  17031   0.015899818366024405    98.41        0        5       42
# 274   1804                    0.0    27.44       33        0        2
# 279  10109  0.0033561969508432224    32.87        0       50      523
# 280  46970                    0.0     0.02        0       50      452
# 282   8525  0.0011259210199519828    18.03        0       50       63
#
#      SWQ-2.5    SWQ-2.6  SWQ-2.7       init        end  frequency (weeks)  \
# 0          1   0.000000      574 2011-07-08 2012-09-16                 12
# 1          0  87.263707       22 2004-09-29 2006-12-05                 12
# 2          1  11.027687      196 2010-09-21 2011-06-30                 12
# 3          1  16.620933      154 2017-09-07 2019-09-18                 12
# 4          0   4.990767       85 2016-08-27 2018-07-01                 12
# ..       ...        ...      ...        ...        ...                ...
# 273      109  11.537613      327 2018-09-19 2024-07-18                 12
# 274        1  31.996976      112 2017-07-19 2024-03-21                 12
# 279     1844  26.921600     2498 2019-04-17 2024-07-16                 12
# 280     1230  36.079518     1513 2022-11-17 2024-07-18                 12
# 282      531  17.646239     5637 2019-04-17 2024-07-17                 12
#
#                                            project_url         status
# 0                          https://github.com/valr/awf  unsustainable
# 1                  https://github.com/arvi/Agila-Theme  unsustainable
# 2          https://github.com/Alois-xx/SerializerTests  unsustainable
# 3    https://github.com/apache/incubator-retired-am...  unsustainable
# 4        https://github.com/apache/incubator-ariatosca  unsustainable
# ..                                                 ...            ...
# 273                   https://github.com/apache/Pulsar    sustainable
# 274                  https://github.com/apache/streams    sustainable
# 279                 https://github.com/apache/NetBeans    sustainable
# 280          https://github.com/apache/incubator-NuttX    sustainable
# 282                    https://github.com/apache/PLC4X    sustainable
#
# [241 rows x 30 columns]

# %%
df_combined[df_combined.isna().any(axis=1)]
# Out:
#      project               COM-1  COM-2 POP-1      STA-1 STA-2 STA-3 STA-4  \
# 98   cordova  1748916.7862903227   1151  1264  11.723477     0    62     0
# 122    Felix   5142729.431256367  25233   896  17.273101   310   322     0
# 231    Sling  2693158.6690781005  42692   698  15.159480  1065   260     0
# 274  streams                 NaN     18   197   6.672142    19    47   -18
#
#      STA-5  STA-6 STA-7 STA-8 STA-9 TEC-1  TEC-2 TEC-3  TEC-4  \
# 98       1   True     0    73    11     2  36686    24     25
# 122      2  False    -7  1365    60     0  69377  2303  35027
# 231      1  False    -8   810    53     0  81086  3266  46606
# 274      1  False    -1    14     9   884  52879   230   1804
#
#                     SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  SWQ-2.5  \
# 98                    0.0     0.00        0        0        0        0
# 122  0.038252949699855106     0.00        0        0        0        0
# 231  0.053478048667115995     0.00        0        0        0        0
# 274                   0.0    27.44       33        0        2        1
#
#        SWQ-2.6  SWQ-2.7       init        end  frequency (weeks)  \
# 98         NaN        0 2012-10-17 2024-07-08                 12
# 122        NaN        0 2007-04-01 2024-07-09                 12
# 231        NaN        0 2009-06-17 2024-08-14                 12
# 274  31.996976      112 2017-07-19 2024-03-21                 12
#
#                            project_url       status
# 98   https://github.com/apache/cordova  sustainable
# 122    https://github.com/apache/Felix  sustainable
# 231    https://github.com/apache/Sling  sustainable
# 274  https://github.com/apache/streams  sustainable

# %%
df_combined = df_combined.dropna()

# %%
df_combined
# Out:
#                          project               COM-1   COM-2  POP-1     STA-1  \
# 0                            awf   307880.1031494253     775    217  1.193703
# 1                    Agila-Theme   5486906.133333334       0    554  2.182067
# 2                SerializerTests   91721.18181818182       0    170  0.772074
# 3    incubator-retired-amaterasu        8753167.2676     123    139  2.028747
# 4            incubator-ariatosca   2021894.153536083    1977    103  1.842574
# ..                           ...                 ...     ...    ...       ...
# 272                        Flink   4324400.851542074  150989  60172  9.579740
# 273                       Pulsar   5351959.264741484   28047  31473  5.828884
# 279                     NetBeans   2133789.239591516    7325   6027  5.248460
# 280              incubator-NuttX   1342959.747826087    2634   6071  1.667351
# 282                        PLC4X  11618259.974489795    1203   2796  5.251198
#
#     STA-2  STA-3 STA-4  STA-5  STA-6 STA-7 STA-8 STA-9  TEC-1  TEC-2 TEC-3  \
# 0       0     11     0      1   True     0    15     1     84  27485    20
# 1       0     50     0      1   True     0     0     0      0    793    20
# 2       0     22     0      1  False     0     0     0      0  51166    22
# 3     -73     27    -1      2  False     3    24     9    426  65317    98
# 4      15     47   -26      2  False    -5    46    14     13  46687    39
# ..    ...    ...   ...    ...    ...   ...   ...   ...    ...    ...   ...
# 272   273  13102    70     16  False    56  4721  1628  12851   7828  6925
# 273  -433   3537  -358     12  False    18  1231   649   7279  64666  3295
# 279    17    835   -41      2  False   -19   417   194   5061   5772  1584
# 280   573   1059  -696      6  False   -13   377   197   2067  67554  6816
# 282   -28    390    74      2  False     1   119    78   3669  72265   395
#
#      TEC-4                  SWQ-1  SWQ-2.1  SWQ-2.2  SWQ-2.3  SWQ-2.4  \
# 0       68    0.22739018087855298     0.00        0        0        0
# 1       10                    0.0     0.00        0        0        8
# 2       81                    0.0     0.00        2        0        0
# 3      715  0.0023589963542783618    22.69        2        0        0
# 4      166    0.05902578796561605    57.47       25        0        0
# ..     ...                    ...      ...      ...      ...      ...
# 272  40618   0.017610098391586823   113.40        0       21       65
# 273  17031   0.015899818366024405    98.41        0        5       42
# 279  10109  0.0033561969508432224    32.87        0       50      523
# 280  46970                    0.0     0.02        0       50      452
# 282   8525  0.0011259210199519828    18.03        0       50       63
#
#      SWQ-2.5    SWQ-2.6  SWQ-2.7       init        end  frequency (weeks)  \
# 0          1   0.000000      574 2011-07-08 2012-09-16                 12
# 1          0  87.263707       22 2004-09-29 2006-12-05                 12
# 2          1  11.027687      196 2010-09-21 2011-06-30                 12
# 3          1  16.620933      154 2017-09-07 2019-09-18                 12
# 4          0   4.990767       85 2016-08-27 2018-07-01                 12
# ..       ...        ...      ...        ...        ...                ...
# 272      214  14.329816      436 2014-12-17 2024-07-16                 12
# 273      109  11.537613      327 2018-09-19 2024-07-18                 12
# 279     1844  26.921600     2498 2019-04-17 2024-07-16                 12
# 280     1230  36.079518     1513 2022-11-17 2024-07-18                 12
# 282      531  17.646239     5637 2019-04-17 2024-07-17                 12
#
#                                            project_url         status
# 0                          https://github.com/valr/awf  unsustainable
# 1                  https://github.com/arvi/Agila-Theme  unsustainable
# 2          https://github.com/Alois-xx/SerializerTests  unsustainable
# 3    https://github.com/apache/incubator-retired-am...  unsustainable
# 4        https://github.com/apache/incubator-ariatosca  unsustainable
# ..                                                 ...            ...
# 272                    https://github.com/apache/Flink    sustainable
# 273                   https://github.com/apache/Pulsar    sustainable
# 279                 https://github.com/apache/NetBeans    sustainable
# 280          https://github.com/apache/incubator-NuttX    sustainable
# 282                    https://github.com/apache/PLC4X    sustainable
#
# [237 rows x 30 columns]

# %%
df_combined.to_csv("all_projects.csv", index=False)

# %%
df_combined.to_csv("all_projects_no_bypass.csv", index=False)
